% %%
tsk = load('output/Job7/Task1.out.mat');

% %%
tsk.errorstruct.message

% %%
flist = dir('/glade/derecho/scratch/tcorrie/regrids/temptARget/ivt.daily.*.*_regridded.*.nc');

% %%
flist(4375).name
% Out:
% ans =
%
%     'ivt.daily.ukesm1-0-ll.r2i1p1f2.d01_regridded.2099.nc'

% %%
sprintf('%d', '1980')
% Out:
% ans =
%
%     '49575648'
